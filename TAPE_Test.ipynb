# %% [markdown]
# <a href="https://colab.research.google.com/github/qfx4yk/TAPE-Practice/blob/main/TAPE_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
pip install scTAPE==1.1.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from TAPE import Deconvolution

# %%
Sigm, Pred = Deconvolution('Kidney_ref.txt', 'Kidney_test.txt',sep='\t',
                           datatype='counts', genelenfile='./GeneLength.txt',
                           mode='overall', adaptive=True,
                           save_model_name = None)
# Out:
# Reading single-cell dataset, this may take 1 min
# Reading dataset is done
# Normalizing raw single cell data with scanpy.pp.normalize_total
# Generating cell fractions using Dirichlet distribution without prior info (actually random)
# RANDOM cell fractions is generated
# You set sparse as True, some cell's fraction will be zero, the probability is 0.5
# Sampling cells to compose pseudo-bulk data
# 5000it [01:29, 56.00it/s]
# Sampling is done
# Reading training data
# Reading is done
# Reading test data
# Reading test data is done
# Using counts data to train model
# Cutting variance...
# Finding intersected genes...
# Intersected gene number is  16793
# Scaling...
# Using minmax scaler...
# training data shape is  (5000, 16793)
# test data shape is  (10, 16793)
# Start training
# 100%|██████████| 128/128 [30:30<00:00, 14.30s/it]
# Training is done
# prediction loss is:
# reconstruction loss is:
# Notice that you are using parameters: mode=overall and adaptive=True
# ...

# %%
Sigm
# Out:
#                                         0610005C13Rik  0610007C21Rik  \
# endothelial cell                             0.451238       0.652795
# epithelial cell of proximal tubule           0.751396       0.602748
# kidney collecting duct epithelial cell       0.461338       0.599338
# macrophage                                   0.417809       0.585199
# natural killer cell                          0.424385       0.626760
#
#                                         0610007L01Rik  0610007N19Rik  \
# endothelial cell                             0.589450       0.430111
# epithelial cell of proximal tubule           0.521393       0.509953
# kidney collecting duct epithelial cell       0.531688       0.561901
# macrophage                                   0.614026       0.393110
# natural killer cell                          0.610065       0.461502
#
#                                         0610007P08Rik  0610007P14Rik  \
# ...

# %%
Pred
# Out:
#    endothelial cell  epithelial cell of proximal tubule  \
# 0          0.193082                            0.159841
# 1          0.194699                            0.179765
# 2          0.181287                            0.164239
# 3          0.179210                            0.144581
# 4          0.185408                            0.154220
# 5          0.186960                            0.187774
# 6          0.176058                            0.149699
# 7          0.164365                            0.158998
# 8          0.208305                            0.158501
# 9          0.176689                            0.174526
#
#    kidney collecting duct epithelial cell  macrophage  natural killer cell
# 0                                0.233737    0.193692             0.219648
# 1                                0.202275    0.239279             0.183982
# 2                                0.233254    0.199576             0.221643
# ...
